# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
height=[]
weight=[]
for i in range(15):
    a=np.random.randint(1,10)
    b=np.random.randint(1,10)
    height.append(a)
    weight.append(b)
n=np.array((height,weight))
a=np.transpose(n)
df=pd.DataFrame(a,columns=("X","Y"))
df
# Out:
#     X  Y
# 0   2  6
# 1   4  6
# 2   4  8
# 3   8  6
# 4   8  6
# 5   8  3
# 6   6  1
# 7   4  2
# 8   6  7
# 9   4  8
# 10  5  3
# 11  6  7
# 12  7  7
# 13  8  9
# 14  2  5

# %%
data=pd.read_csv("Book2.csv")
data
# Out:
#     s_no.  X  Y
# 0       1  6  5
# 1       2  4  8
# 2       3  7  6
# 3       4  6  5
# 4       5  9  1
# 5       6  5  5
# 6       7  7  1
# 7       8  7  1
# 8       9  6  1
# 9      10  9  6
# 10     11  7  3
# 11     12  6  2
# 12     13  1  5
# 13     14  5  3

# %%
plt.scatter(df["X"],df["Y"],marker="$\$$",color="r")
plt.show()

# %%
print(data["X"])
# Out:
# 0     6
# 1     4
# 2     7
# 3     6
# 4     9
# 5     5
# 6     7
# 7     7
# 8     6
# 9     9
# 10    7
# 11    6
# 12    1
# 13    5
# Name: X, dtype: int64

# %%
print(data['Y'])
# Out:
# 0     5
# 1     8
# 2     6
# 3     5
# 4     1
# 5     5
# 6     1
# 7     1
# 8     1
# 9     6
# 10    3
# 11    2
# 12    5
# 13    3
# Name: Y, dtype: int64

# %%
x=data.to_numpy().reshape(-1,1)
b#method 1 to reshape dataframe
# Out:
# array([[ 1],
#        [ 6],
#        [ 5],
#        [ 2],
#        [ 4],
#        [ 8],
#        [ 3],
#        [ 7],
#        [ 6],
#        [ 4],
#        [ 6],
#        [ 5],
#        [ 5],
#        [ 9],
#        [ 1],
#        [ 6],
#        [ 5],
#        [ 5],
#        [ 7],
#        [ 7],
#        [ 1],
#        [ 8],
#        [ 7],
#        [ 1],
#        [ 9],
#        [ 6],
#        [ 1],
#        [10],
#        [ 9],
#        [ 6],
#        [11],
#        [ 7],
#        [ 3],
#        [12],
#        [ 6],
#        [ 2],
#        [13],
#        [ 1],
#        [ 5],
#        [14],
#        [ 5],
#        [ 3]])

# %%
y=np.array(data).reshape(-1,1)
c#method2 for reshaping dataframe
# Out:
# array([[ 1],
#        [ 6],
#        [ 5],
#        [ 2],
#        [ 4],
#        [ 8],
#        [ 3],
#        [ 7],
#        [ 6],
#        [ 4],
#        [ 6],
#        [ 5],
#        [ 5],
#        [ 9],
#        [ 1],
#        [ 6],
#        [ 5],
#        [ 5],
#        [ 7],
#        [ 7],
#        [ 1],
#        [ 8],
#        [ 7],
#        [ 1],
#        [ 9],
#        [ 6],
#        [ 1],
#        [10],
#        [ 9],
#        [ 6],
#        [11],
#        [ 7],
#        [ 3],
#        [12],
#        [ 6],
#        [ 2],
#        [13],
#        [ 1],
#        [ 5],
#        [14],
#        [ 5],
#        [ 3]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2)
#0.2=20% in training

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([[ 7.],
#        [ 4.],
#        [ 6.],
#        [ 5.],
#        [10.],
#        [ 3.],
#        [ 1.],
#        [ 2.],
#        [ 5.]])
